# %%
from graph_gen import graph_gen as gg
from forbidden_zones import forbidden_random as fr
from graph_drawing import draw_graph as dg
from graph_search import Astar_rec

# %%
# %%timeit
e = 1
N = 10**e
M = 10**e
graph = gg(N, M, d=1)
graph
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 21982.73it/s]
# {(0, 0): [(1, (0, 1)), (1.41, (1, 1)), (1, (1, 0))],
#  (0, 1): [(1, (0, 2)),
#   (1.41, (1, 2)),
#   (1, (1, 1)),
#   (1.41, (1, 0)),
#   (1, (0, 0))],
#  (0, 2): [(1, (0, 3)),
#   (1.41, (1, 3)),
#   (1, (1, 2)),
#   (1.41, (1, 1)),
#   (1, (0, 1))],
#  (0, 3): [(1, (0, 4)),
#   (1.41, (1, 4)),
#   (1, (1, 3)),
#   (1.41, (1, 2)),
#   (1, (0, 2))],
#  (0, 4): [(1, (0, 5)),
#   (1.41, (1, 5)),
#   (1, (1, 4)),
#   (1.41, (1, 3)),
#   (1, (0, 3))],
#  (0, 5): [(1, (0, 6)),
#   (1.41, (1, 6)),
#   (1, (1, 5)),
#   (1.41, (1, 4)),
#   (1, (0, 4))],
#  (0, 6): [(1, (0, 7)),
#   (1.41, (1, 7)),
#   (1, (1, 6)),
#   (1.41, (1, 5)),
#   (1, (0, 5))],
#  (0, 7): [(1, (0, 8)),
#   (1.41, (1, 8)),
#   (1, (1, 7)),
#   (1.41, (1, 6)),
#   (1, (0, 6))],
#  (0, 8): [(1, (0, 9)),
#   (1.41, (1, 9)),
#   (1, (1, 8)),
#   (1.41, (1, 7)),
#   (1, (0, 7))],
#  (0, 9): [(1, (1, 9)), (1.41, (1, 8)), (1, (0, 8))],
#  (1, 0): [(1, (0, 0)),
#   (1.41, (0, 1)),
#   (1, (1, 1)),
#   (1.41, (2, 1)),
#   (1, (2, 0))],
#  (1, 1): [(1.41, (0, 0)),
#   (1, (0, 1)),
#   (1.41, (0, 2)),
#   (1, (1, 2)),
#   (1.41, (2, 2)),
#   (1, (2, 1)),
#   (1.41, (2, 0)),
#   (1, (1, 0))],
#  (1, 2): [(1.41, (0, 1)),
#   (1, (0, 2)),
#   (1.41, (0, 3)),
#   (1, (1, 3)),
#   (1.41, (2, 3)),
#   (1, (2, 2)),
#   (1.41, (2, 1)),
#   (1, (1, 1))],
#  (1, 3): [(1.41, (0, 2)),
#   (1, (0, 3)),
#   (1.41, (0, 4)),
#   (1, (1, 4)),
#   (1.41, (2, 4)),
#   (1, (2, 3)),
#   (1.41, (2, 2)),
#   (1, (1, 2))],
#  (1, 4): [(1.41, (0, 3)),
#   (1, (0, 4)),
#   (1.41, (0, 5)),
#   (1, (1, 5)),
#   (1.41, (2, 5)),
#   (1, (2, 4)),
#   (1.41, (2, 3)),
#   (1, (1, 3))],
#  (1, 5): [(1.41, (0, 4)),
#   (1, (0, 5)),
#   (1.41, (0, 6)),
#   (1, (1, 6)),
#   (1.41, (2, 6)),
#   (1, (2, 5)),
#   (1.41, (2, 4)),
#   (1, (1, 4))],
#  (1, 6): [(1.41, (0, 5)),
#   (1, (0, 6)),
#   (1.41, (0, 7)),
#   (1, (1, 7)),
#   (1.41, (2, 7)),
#   (1, (2, 6)),
#   (1.41, (2, 5)),
#   (1, (1, 5))],
#  (1, 7): [(1.41, (0, 6)),
#   (1, (0, 7)),
#   (1.41, (0, 8)),
#   (1, (1, 8)),
#   (1.41, (2, 8)),
#   (1, (2, 7)),
#   (1.41, (2, 6)),
#   (1, (1, 6))],
#  (1, 8): [(1.41, (0, 7)),
#   (1, (0, 8)),
#   (1.41, (0, 9)),
#   (1, (1, 9)),
#   (1.41, (2, 9)),
#   (1, (2, 8)),
#   (1.41, (2, 7)),
#   (1, (1, 7))],
#  (1, 9): [(1.41, (0, 8)),
#   (1, (0, 9)),
#   (1, (2, 9)),
#   (1.41, (2, 8)),
#   (1, (1, 8))],
#  (2, 0): [(1, (1, 0)),
#   (1.41, (1, 1)),
#   (1, (2, 1)),
#   (1.41, (3, 1)),
#   (1, (3, 0))],
#  (2, 1): [(1.41, (1, 0)),
#   (1, (1, 1)),
#   (1.41, (1, 2)),
#   (1, (2, 2)),
#   (1.41, (3, 2)),
#   (1, (3, 1)),
#   (1.41, (3, 0)),
#   (1, (2, 0))],
#  (2, 2): [(1.41, (1, 1)),
#   (1, (1, 2)),
#   (1.41, (1, 3)),
#   (1, (2, 3)),
#   (1.41, (3, 3)),
#   (1, (3, 2)),
#   (1.41, (3, 1)),
#   (1, (2, 1))],
#  (2, 3): [(1.41, (1, 2)),
#   (1, (1, 3)),
#   (1.41, (1, 4)),
#   (1, (2, 4)),
#   (1.41, (3, 4)),
#   (1, (3, 3)),
#   (1.41, (3, 2)),
#   (1, (2, 2))],
#  (2, 4): [(1.41, (1, 3)),
#   (1, (1, 4)),
#   (1.41, (1, 5)),
#   (1, (2, 5)),
#   (1.41, (3, 5)),
#   (1, (3, 4)),
#   (1.41, (3, 3)),
#   (1, (2, 3))],
#  (2, 5): [(1.41, (1, 4)),
#   (1, (1, 5)),
#   (1.41, (1, 6)),
#   (1, (2, 6)),
#   (1.41, (3, 6)),
#   (1, (3, 5)),
#   (1.41, (3, 4)),
#   (1, (2, 4))],
#  (2, 6): [(1.41, (1, 5)),
#   (1, (1, 6)),
#   (1.41, (1, 7)),
#   (1, (2, 7)),
#   (1.41, (3, 7)),
#   (1, (3, 6)),
#   (1.41, (3, 5)),
#   (1, (2, 5))],
#  (2, 7): [(1.41, (1, 6)),
#   (1, (1, 7)),
#   (1.41, (1, 8)),
#   (1, (2, 8)),
#   (1.41, (3, 8)),
#   (1, (3, 7)),
#   (1.41, (3, 6)),
#   (1, (2, 6))],
#  (2, 8): [(1.41, (1, 7)),
#   (1, (1, 8)),
#   (1.41, (1, 9)),
#   (1, (2, 9)),
#   (1.41, (3, 9)),
#   (1, (3, 8)),
#   (1.41, (3, 7)),
#   (1, (2, 7))],
#  (2, 9): [(1.41, (1, 8)),
#   (1, (1, 9)),
#   (1, (3, 9)),
#   (1.41, (3, 8)),
#   (1, (2, 8))],
#  (3, 0): [(1, (2, 0)),
#   (1.41, (2, 1)),
#   (1, (3, 1)),
#   (1.41, (4, 1)),
#   (1, (4, 0))],
#  (3, 1): [(1.41, (2, 0)),
#   (1, (2, 1)),
#   (1.41, (2, 2)),
#   (1, (3, 2)),
#   (1.41, (4, 2)),
#   (1, (4, 1)),
#   (1.41, (4, 0)),
#   (1, (3, 0))],
#  (3, 2): [(1.41, (2, 1)),
#   (1, (2, 2)),
#   (1.41, (2, 3)),
#   (1, (3, 3)),
#   (1.41, (4, 3)),
#   (1, (4, 2)),
#   (1.41, (4, 1)),
#   (1, (3, 1))],
#  (3, 3): [(1.41, (2, 2)),
#   (1, (2, 3)),
#   (1.41, (2, 4)),
#   (1, (3, 4)),
#   (1.41, (4, 4)),
#   (1, (4, 3)),
#   (1.41, (4, 2)),
#   (1, (3, 2))],
#  (3, 4): [(1.41, (2, 3)),
#   (1, (2, 4)),
#   (1.41, (2, 5)),
#   (1, (3, 5)),
#   (1.41, (4, 5)),
#   (1, (4, 4)),
#   (1.41, (4, 3)),
#   (1, (3, 3))],
#  (3, 5): [(1.41, (2, 4)),
#   (1, (2, 5)),
#   (1.41, (2, 6)),
#   (1, (3, 6)),
#   (1.41, (4, 6)),
#   (1, (4, 5)),
#   (1.41, (4, 4)),
#   (1, (3, 4))],
#  (3, 6): [(1.41, (2, 5)),
#   (1, (2, 6)),
#   (1.41, (2, 7)),
#   (1, (3, 7)),
#   (1.41, (4, 7)),
#   (1, (4, 6)),
#   (1.41, (4, 5)),
#   (1, (3, 5))],
#  (3, 7): [(1.41, (2, 6)),
#   (1, (2, 7)),
#   (1.41, (2, 8)),
#   (1, (3, 8)),
#   (1.41, (4, 8)),
#   (1, (4, 7)),
#   (1.41, (4, 6)),
#   (1, (3, 6))],
#  (3, 8): [(1.41, (2, 7)),
#   (1, (2, 8)),
#   (1.41, (2, 9)),
#   (1, (3, 9)),
#   (1.41, (4, 9)),
#   (1, (4, 8)),
#   (1.41, (4, 7)),
#   (1, (3, 7))],
#  (3, 9): [(1.41, (2, 8)),
#   (1, (2, 9)),
#   (1, (4, 9)),
#   (1.41, (4, 8)),
#   (1, (3, 8))],
#  (4, 0): [(1, (3, 0)),
#   (1.41, (3, 1)),
#   (1, (4, 1)),
#   (1.41, (5, 1)),
#   (1, (5, 0))],
#  (4, 1): [(1.41, (3, 0)),
#   (1, (3, 1)),
#   (1.41, (3, 2)),
#   (1, (4, 2)),
#   (1.41, (5, 2)),
#   (1, (5, 1)),
#   (1.41, (5, 0)),
#   (1, (4, 0))],
#  (4, 2): [(1.41, (3, 1)),
#   (1, (3, 2)),
#   (1.41, (3, 3)),
#   (1, (4, 3)),
#   (1.41, (5, 3)),
#   (1, (5, 2)),
#   (1.41, (5, 1)),
#   (1, (4, 1))],
#  (4, 3): [(1.41, (3, 2)),
#   (1, (3, 3)),
#   (1.41, (3, 4)),
#   (1, (4, 4)),
#   (1.41, (5, 4)),
#   (1, (5, 3)),
#   (1.41, (5, 2)),
#   (1, (4, 2))],
#  (4, 4): [(1.41, (3, 3)),
#   (1, (3, 4)),
#   (1.41, (3, 5)),
#   (1, (4, 5)),
#   (1.41, (5, 5)),
#   (1, (5, 4)),
#   (1.41, (5, 3)),
#   (1, (4, 3))],
#  (4, 5): [(1.41, (3, 4)),
#   (1, (3, 5)),
#   (1.41, (3, 6)),
#   (1, (4, 6)),
#   (1.41, (5, 6)),
#   (1, (5, 5)),
#   (1.41, (5, 4)),
#   (1, (4, 4))],
#  (4, 6): [(1.41, (3, 5)),
#   (1, (3, 6)),
#   (1.41, (3, 7)),
#   (1, (4, 7)),
#   (1.41, (5, 7)),
#   (1, (5, 6)),
#   (1.41, (5, 5)),
#   (1, (4, 5))],
#  (4, 7): [(1.41, (3, 6)),
#   (1, (3, 7)),
#   (1.41, (3, 8)),
#   (1, (4, 8)),
#   (1.41, (5, 8)),
#   (1, (5, 7)),
#   (1.41, (5, 6)),
#   (1, (4, 6))],
#  (4, 8): [(1.41, (3, 7)),
#   (1, (3, 8)),
#   (1.41, (3, 9)),
#   (1, (4, 9)),
#   (1.41, (5, 9)),
#   (1, (5, 8)),
#   (1.41, (5, 7)),
#   (1, (4, 7))],
#  (4, 9): [(1.41, (3, 8)),
#   (1, (3, 9)),
#   (1, (5, 9)),
#   (1.41, (5, 8)),
#   (1, (4, 8))],
#  (5, 0): [(1, (4, 0)),
#   (1.41, (4, 1)),
#   (1, (5, 1)),
#   (1.41, (6, 1)),
#   (1, (6, 0))],
#  (5, 1): [(1.41, (4, 0)),
#   (1, (4, 1)),
#   (1.41, (4, 2)),
#   (1, (5, 2)),
#   (1.41, (6, 2)),
#   (1, (6, 1)),
#   (1.41, (6, 0)),
#   (1, (5, 0))],
#  (5, 2): [(1.41, (4, 1)),
#   (1, (4, 2)),
#   (1.41, (4, 3)),
#   (1, (5, 3)),
#   (1.41, (6, 3)),
#   (1, (6, 2)),
#   (1.41, (6, 1)),
#   (1, (5, 1))],
#  (5, 3): [(1.41, (4, 2)),
#   (1, (4, 3)),
#   (1.41, (4, 4)),
#   (1, (5, 4)),
#   (1.41, (6, 4)),
#   (1, (6, 3)),
#   (1.41, (6, 2)),
#   (1, (5, 2))],
#  (5, 4): [(1.41, (4, 3)),
#   (1, (4, 4)),
#   (1.41, (4, 5)),
#   (1, (5, 5)),
#   (1.41, (6, 5)),
#   (1, (6, 4)),
#   (1.41, (6, 3)),
#   (1, (5, 3))],
#  (5, 5): [(1.41, (4, 4)),
#   (1, (4, 5)),
#   (1.41, (4, 6)),
#   (1, (5, 6)),
#   (1.41, (6, 6)),
#   (1, (6, 5)),
#   (1.41, (6, 4)),
#   (1, (5, 4))],
#  (5, 6): [(1.41, (4, 5)),
#   (1, (4, 6)),
#   (1.41, (4, 7)),
#   (1, (5, 7)),
#   (1.41, (6, 7)),
#   (1, (6, 6)),
#   (1.41, (6, 5)),
#   (1, (5, 5))],
#  (5, 7): [(1.41, (4, 6)),
#   (1, (4, 7)),
#   (1.41, (4, 8)),
#   (1, (5, 8)),
#   (1.41, (6, 8)),
#   (1, (6, 7)),
#   (1.41, (6, 6)),
#   (1, (5, 6))],
#  (5, 8): [(1.41, (4, 7)),
#   (1, (4, 8)),
#   (1.41, (4, 9)),
#   (1, (5, 9)),
#   (1.41, (6, 9)),
#   (1, (6, 8)),
#   (1.41, (6, 7)),
#   (1, (5, 7))],
#  (5, 9): [(1.41, (4, 8)),
#   (1, (4, 9)),
#   (1, (6, 9)),
#   (1.41, (6, 8)),
#   (1, (5, 8))],
#  (6, 0): [(1, (5, 0)),
#   (1.41, (5, 1)),
#   (1, (6, 1)),
#   (1.41, (7, 1)),
#   (1, (7, 0))],
#  (6, 1): [(1.41, (5, 0)),
#   (1, (5, 1)),
#   (1.41, (5, 2)),
#   (1, (6, 2)),
#   (1.41, (7, 2)),
#   (1, (7, 1)),
#   (1.41, (7, 0)),
#   (1, (6, 0))],
#  (6, 2): [(1.41, (5, 1)),
#   (1, (5, 2)),
#   (1.41, (5, 3)),
#   (1, (6, 3)),
#   (1.41, (7, 3)),
#   (1, (7, 2)),
#   (1.41, (7, 1)),
#   (1, (6, 1))],
#  (6, 3): [(1.41, (5, 2)),
#   (1, (5, 3)),
#   (1.41, (5, 4)),
#   (1, (6, 4)),
#   (1.41, (7, 4)),
#   (1, (7, 3)),
#   (1.41, (7, 2)),
#   (1, (6, 2))],
#  (6, 4): [(1.41, (5, 3)),
#   (1, (5, 4)),
#   (1.41, (5, 5)),
#   (1, (6, 5)),
#   (1.41, (7, 5)),
#   (1, (7, 4)),
#   (1.41, (7, 3)),
#   (1, (6, 3))],
#  (6, 5): [(1.41, (5, 4)),
#   (1, (5, 5)),
#   (1.41, (5, 6)),
#   (1, (6, 6)),
#   (1.41, (7, 6)),
#   (1, (7, 5)),
#   (1.41, (7, 4)),
#   (1, (6, 4))],
#  (6, 6): [(1.41, (5, 5)),
#   (1, (5, 6)),
#   (1.41, (5, 7)),
#   (1, (6, 7)),
#   (1.41, (7, 7)),
#   (1, (7, 6)),
#   (1.41, (7, 5)),
#   (1, (6, 5))],
#  (6, 7): [(1.41, (5, 6)),
#   (1, (5, 7)),
#   (1.41, (5, 8)),
#   (1, (6, 8)),
#   (1.41, (7, 8)),
#   (1, (7, 7)),
#   (1.41, (7, 6)),
#   (1, (6, 6))],
#  (6, 8): [(1.41, (5, 7)),
#   (1, (5, 8)),
#   (1.41, (5, 9)),
#   (1, (6, 9)),
#   (1.41, (7, 9)),
#   (1, (7, 8)),
#   (1.41, (7, 7)),
#   (1, (6, 7))],
#  (6, 9): [(1.41, (5, 8)),
#   (1, (5, 9)),
#   (1, (7, 9)),
#   (1.41, (7, 8)),
#   (1, (6, 8))],
#  (7, 0): [(1, (6, 0)),
#   (1.41, (6, 1)),
#   (1, (7, 1)),
#   (1.41, (8, 1)),
#   (1, (8, 0))],
#  (7, 1): [(1.41, (6, 0)),
#   (1, (6, 1)),
#   (1.41, (6, 2)),
#   (1, (7, 2)),
#   (1.41, (8, 2)),
#   (1, (8, 1)),
#   (1.41, (8, 0)),
#   (1, (7, 0))],
#  (7, 2): [(1.41, (6, 1)),
#   (1, (6, 2)),
#   (1.41, (6, 3)),
#   (1, (7, 3)),
#   (1.41, (8, 3)),
#   (1, (8, 2)),
#   (1.41, (8, 1)),
#   (1, (7, 1))],
#  (7, 3): [(1.41, (6, 2)),
#   (1, (6, 3)),
#   (1.41, (6, 4)),
#   (1, (7, 4)),
#   (1.41, (8, 4)),
#   (1, (8, 3)),
#   (1.41, (8, 2)),
#   (1, (7, 2))],
#  (7, 4): [(1.41, (6, 3)),
#   (1, (6, 4)),
#   (1.41, (6, 5)),
#   (1, (7, 5)),
#   (1.41, (8, 5)),
#   (1, (8, 4)),
#   (1.41, (8, 3)),
#   (1, (7, 3))],
#  (7, 5): [(1.41, (6, 4)),
#   (1, (6, 5)),
#   (1.41, (6, 6)),
#   (1, (7, 6)),
#   (1.41, (8, 6)),
#   (1, (8, 5)),
#   (1.41, (8, 4)),
#   (1, (7, 4))],
#  (7, 6): [(1.41, (6, 5)),
#   (1, (6, 6)),
#   (1.41, (6, 7)),
#   (1, (7, 7)),
#   (1.41, (8, 7)),
#   (1, (8, 6)),
#   (1.41, (8, 5)),
#   (1, (7, 5))],
#  (7, 7): [(1.41, (6, 6)),
#   (1, (6, 7)),
#   (1.41, (6, 8)),
#   (1, (7, 8)),
#   (1.41, (8, 8)),
#   (1, (8, 7)),
#   (1.41, (8, 6)),
#   (1, (7, 6))],
#  (7, 8): [(1.41, (6, 7)),
#   (1, (6, 8)),
#   (1.41, (6, 9)),
#   (1, (7, 9)),
#   (1.41, (8, 9)),
#   (1, (8, 8)),
#   (1.41, (8, 7)),
#   (1, (7, 7))],
#  (7, 9): [(1.41, (6, 8)),
#   (1, (6, 9)),
#   (1, (8, 9)),
#   (1.41, (8, 8)),
#   (1, (7, 8))],
#  (8, 0): [(1, (7, 0)),
#   (1.41, (7, 1)),
#   (1, (8, 1)),
#   (1.41, (9, 1)),
#   (1, (9, 0))],
#  (8, 1): [(1.41, (7, 0)),
#   (1, (7, 1)),
#   (1.41, (7, 2)),
#   (1, (8, 2)),
#   (1.41, (9, 2)),
#   (1, (9, 1)),
#   (1.41, (9, 0)),
#   (1, (8, 0))],
#  (8, 2): [(1.41, (7, 1)),
#   (1, (7, 2)),
#   (1.41, (7, 3)),
#   (1, (8, 3)),
#   (1.41, (9, 3)),
#   (1, (9, 2)),
#   (1.41, (9, 1)),
#   (1, (8, 1))],
#  (8, 3): [(1.41, (7, 2)),
#   (1, (7, 3)),
#   (1.41, (7, 4)),
#   (1, (8, 4)),
#   (1.41, (9, 4)),
#   (1, (9, 3)),
#   (1.41, (9, 2)),
#   (1, (8, 2))],
#  (8, 4): [(1.41, (7, 3)),
#   (1, (7, 4)),
#   (1.41, (7, 5)),
#   (1, (8, 5)),
#   (1.41, (9, 5)),
#   (1, (9, 4)),
#   (1.41, (9, 3)),
#   (1, (8, 3))],
#  (8, 5): [(1.41, (7, 4)),
#   (1, (7, 5)),
#   (1.41, (7, 6)),
#   (1, (8, 6)),
#   (1.41, (9, 6)),
#   (1, (9, 5)),
#   (1.41, (9, 4)),
#   (1, (8, 4))],
#  (8, 6): [(1.41, (7, 5)),
#   (1, (7, 6)),
#   (1.41, (7, 7)),
#   (1, (8, 7)),
#   (1.41, (9, 7)),
#   (1, (9, 6)),
#   (1.41, (9, 5)),
#   (1, (8, 5))],
#  (8, 7): [(1.41, (7, 6)),
#   (1, (7, 7)),
#   (1.41, (7, 8)),
#   (1, (8, 8)),
#   (1.41, (9, 8)),
#   (1, (9, 7)),
#   (1.41, (9, 6)),
#   (1, (8, 6))],
#  (8, 8): [(1.41, (7, 7)),
#   (1, (7, 8)),
#   (1.41, (7, 9)),
#   (1, (8, 9)),
#   (1.41, (9, 9)),
#   (1, (9, 8)),
#   (1.41, (9, 7)),
#   (1, (8, 7))],
#  (8, 9): [(1.41, (7, 8)),
#   (1, (7, 9)),
#   (1, (9, 9)),
#   (1.41, (9, 8)),
#   (1, (8, 8))],
#  (9, 0): [(1, (8, 0)), (1.41, (8, 1)), (1, (9, 1))],
#  (9, 1): [(1.41, (8, 0)),
#   (1, (8, 1)),
#   (1.41, (8, 2)),
#   (1, (9, 2)),
#   (1, (9, 0))],
#  (9, 2): [(1.41, (8, 1)),
#   (1, (8, 2)),
#   (1.41, (8, 3)),
#   (1, (9, 3)),
#   (1, (9, 1))],
#  (9, 3): [(1.41, (8, 2)),
#   (1, (8, 3)),
#   (1.41, (8, 4)),
#   (1, (9, 4)),
#   (1, (9, 2))],
#  (9, 4): [(1.41, (8, 3)),
#   (1, (8, 4)),
#   (1.41, (8, 5)),
#   (1, (9, 5)),
#   (1, (9, 3))],
#  (9, 5): [(1.41, (8, 4)),
#   (1, (8, 5)),
#   (1.41, (8, 6)),
#   (1, (9, 6)),
#   (1, (9, 4))],
#  (9, 6): [(1.41, (8, 5)),
#   (1, (8, 6)),
#   (1.41, (8, 7)),
#   (1, (9, 7)),
#   (1, (9, 5))],
#  (9, 7): [(1.41, (8, 6)),
#   (1, (8, 7)),
#   (1.41, (8, 8)),
#   (1, (9, 8)),
#   (1, (9, 6))],
#  (9, 8): [(1.41, (8, 7)),
#   (1, (8, 8)),
#   (1.41, (8, 9)),
#   (1, (9, 9)),
#   (1, (9, 7))],
#  (9, 9): [(1.41, (8, 8)), (1, (8, 9)), (1, (9, 8))]}

# %%
N = 18
M = 50
k = 10
start = (5,3)
goal = (N-5, M-9)
forb = fr(N, M, k) 
# x = (0,5)
# forb = forb.union([x])
# print(forb)
graph = gg(N, M, forbidden=forb)
result = Astar_rec(graph, start, goal)
dg(N, M, result, start, goal, forb)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 3945.31it/s]
# ..................................................
# ..................................................
# ..................................................
# X.................................................
# ..................................................
# ...S..............................................
# ....#......X................X.....................
# X....#............................................
# ......#..........X..............................X.
# .......#..........................................
# ........#.........................................
# .........#........................................
# ........X.#.......................................
# ...........##############################F........
# ..................................................
# ....................X.............................
# ..................................................
# ..........X....................X..................

# %%
import matplotlib.pyplot as plt
x = np.arange(1, 101, 5)
y = np.arange(1, 101, 5)
plt.scatter(x,y+np.random.normal(loc=0, scale=0.9, size=len(y)))
plt.plot(x,y)
